# %%
# !python "create_tables.py"

# %%
# !python "etl.py"
# Out:
# 74 files found in data/song_data
# ['SOMZWCG12A8C13C480', "I Didn't Mean To", 'ARD7TVE1187B99BFB1', 0, 218.93179]
# INSERT INTO songs (ID, title, artist_id, year, duration) VALUES (%s, %s, %s, %s,%s)
#
# ['ARD7TVE1187B99BFB1', 'Casual', 'California - LA', None, None]
# INSERT INTO artists (ID, name, location, latitude, longitude) VALUES (%s, %s, %s, %s,%s)
#
#
# 1/74 files processed.
# ['SOUDSGM12AC9618304', 'Insatiable (Instrumental Version)', 'ARNTLGG11E2835DDB9', 0, 266.39628]
# INSERT INTO songs (ID, title, artist_id, year, duration) VALUES (%s, %s, %s, %s,%s)
#
# ['ARNTLGG11E2835DDB9', 'Clp', '', None, None]
# INSERT INTO artists (ID, name, location, latitude, longitude) VALUES (%s, %s, %s, %s,%s)
#
#
# 2/74 files processed.
# ['SOIAZJW12AB01853F1', 'Pink World', 'AR8ZCNI1187B9A069B', 1984, 269.81832]
# INSERT INTO songs (ID, title, artist_id, year, duration) VALUES (%s, %s, %s, %s,%s)
#
# ['AR8ZCNI1187B9A069B', 'Planet P Project', '', None, None]
# ...
